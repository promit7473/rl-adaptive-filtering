# %% [markdown]
# # Meta-Learned Step-Size and Leakage Control: Cloud GPU Pipeline
#
# This notebook allows you to run the full production pipeline for **"Meta-Learned Step-Size and Leakage Control for Robust Adaptive Filtering"** on a **free Cloud GPU (T4 / P100)** in Google Colab or Kaggle.
#
# ### Prerequisite:
# Go to **Runtime** -> **Change runtime type** -> Select **GPU** (T4 GPU is perfect) -> Click **Save**.

# %% [markdown]
# ## 1. Persist Results (Google Drive Integration)
# To ensure your trained checkpoints and results are not lost when your runtime terminates, mount your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone Repository & Setup Environment
# Clone your repository, navigate to the folder, install the requirements, and install the library in editable mode.

# %%
# Clone the repository
# !git clone https://github.com/promit7473/rl-adaptive-filtering.git
# %cd rl-adaptive-filtering

# Install dependencies
# !pip install -r requirements.txt
# !pip install -e .

# Verify GPU is visible to PyTorch
import torch
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Device Name:", torch.cuda.get_device_name(0))

# %% [markdown]
# ## 3. Run Production Pipeline (Hybrid BPTT+RL, BPTT, RL-only, and Evaluation)
# Run the full pipeline. The script automatically checkpoints every 500 iterations and supports resuming, making it completely resilient to Colab disconnections.

# %%
# Run the full pipeline script
# !PYTHONPATH=. python3 scripts/_run_pipeline.py

# %% [markdown]
# ## 4. Copy Results Back to Google Drive
# Once training and evaluation are complete, back up the checkpoints and CSV results back to your Google Drive.

# %%
# Create results directory on Google Drive
# !mkdir -p /content/drive/MyDrive/rl_adaptive_filtering_results/

# Copy results
# !cp -r results/* /content/drive/MyDrive/rl_adaptive_filtering_results/
print("Results successfully backed up to Google Drive!")
